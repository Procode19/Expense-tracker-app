# %% [markdown]
# # Expense Tracker App
# This notebook demonstrates synthetic expense data creation, cleaning, and a quick preview of the dataset.

# %%
import pandas as pd
from src.expense_tracker import generate_synthetic_expense_data, clean_expense_data

df_raw = generate_synthetic_expense_data(num_records=200)
df_clean = clean_expense_data(df_raw)
df_clean.head()

# %% [markdown]
# ## Next steps
# Use `main.py` to generate complete chart output and `app.py` to run the interactive Streamlit dashboard.
